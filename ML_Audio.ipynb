# %% [markdown]
# <a href="https://colab.research.google.com/github/sam505/Machine_Learning/blob/master/ML_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import wave
from scipy.io import wavfile
import soundfile
import matplotlib.pyplot as plt
import librosa

# %%
audio_path = "/content/PI240.wav"
audio_file = wave.open(audio_path)
print("Framerate: {}, Total frames: {}, Duration: {}".format(audio_file.getframerate(), audio_file.getnframes(), (audio_file.getnframes()/audio_file.getframerate())))
# Out:
# Framerate: 240000, Total frames: 72000000, Duration: 300.0

# %%
rate, data = wavfile.read(audio_path)
print(rate)
print(data)
print(data.shape)
# Out:
# 240000
# [-353 -354 -353 ... -337 -336 -337]
# (72000000,)

# %%
plt.plot(data, '-',)
plt.show()

# %%
plt.figure(figsize=(16, 4))
plt.plot(data[:500], '.'); plt.plot(data[:500], '-');

# %%
new_data, _ = librosa.core.load(audio_path, sr=16000, res_type='kaiser_fast')

# %%
print(new_data.shape)
# Out:
# (4800000,)
